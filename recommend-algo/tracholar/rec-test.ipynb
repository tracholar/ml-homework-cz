# %%
from movielens_dataset import MovieLens

# %%
import movielens_dataset
reload(movielens_dataset)
# Out:
# <module 'movielens_dataset' from 'movielens_dataset.py'>

# %%
dataset = MovieLens()

# %%
df = dataset.get_user_like_list()

# %%
df.apply(lambda x: x.movieId.tolist())
# Out:
# userId
# 1         [151, 223, 253, 260, 293, 296, 318, 541, 1036,...
# 2         [3, 62, 70, 110, 260, 266, 480, 541, 589, 908,...
# 3         [1, 32, 50, 175, 223, 260, 316, 318, 329, 457,...
# 4         [10, 350, 356, 368, 370, 377, 431, 454, 480, 4...
# 5         [11, 62, 110, 141, 150, 260, 282, 316, 318, 35...
# 6         [1, 7, 17, 52, 62, 140, 141, 260, 494, 628, 64...
# 7         [11, 260, 348, 356, 364, 440, 480, 539, 553, 5...
# 8         [1, 3, 10, 21, 47, 48, 110, 150, 161, 207, 236...
# 9         [356, 858, 1923, 1997, 2706, 2841, 2959, 3798,...
# 10        [1, 11, 25, 260, 527, 858, 912, 969, 1136, 119...
# 11        [1, 32, 39, 110, 150, 158, 160, 165, 170, 172,...
# 12        [1, 34, 36, 104, 110, 260, 344, 356, 364, 380,...
# 13        [1, 11, 32, 47, 95, 110, 150, 160, 161, 185, 2...
# 14        [1, 17, 62, 150, 252, 260, 277, 314, 339, 356,...
# 15        [34, 150, 246, 356, 364, 457, 474, 515, 527, 5...
# ...

# %%
df.rating

# %%
s = pd.Series([1,2,3,4])

# %%
s.tolist
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64
